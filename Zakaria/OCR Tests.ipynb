# %%
import cv2
import pytesseract

img = cv2.imread('TOS.png')

# %%
path = r"C:/Users/zakaria.bekkar/AppData/Local/Programs/Tesseract-OCR/tesseract.exe"

# %%
pytesseract.pytesseract.tesseract_cmd = path
pytesseract.pytesseract.linesep = '\n'

# %%
print(pytesseract.image_to_string(img))
# Out:
# 4. CONTEXTE GENERAL DU PROJET.
#
#
#
# 5
# 4.4, LES GRANDS DEFIS ENERGETIQUES . ne )
# 4.2. _ LAPROGRAMMATION DU DEVELOPPEMENT DES ENERGIES RENOUVELABLES EN FRANCE... cece e-6)
# 4.3. CONTEXTE DU PROJET PROVENCE GRAND LARGE ... 7
# 1.3.1. Un projet développé depuis 2011... ee A
# 1.3.2. L’appel & projets de 2015 (AAP) .....0.0csccsceccvseseeininnitctntnttinnneentstnnecsee®
#
#
#
# 2. CONTEXTE ADMINISTRATIF DU PROGRAMME DE TRAVAUX ..
#
#
#
# 2.1 PRESENTATION DES MAITRES D'OUVRAGE. cess eeeneeeeeeeeeseteetenetieeseneeetneeseeeeeeeeeeetee
# 2.2 CONTEXTE REGLEMENTAIRE DE L'ETUDE D'IMPACT «o.oo eeceseceeseseseseeeeeseeeeeeneneeeeeeeeeeneeecete
# 2.3. NOTION DE PROGRAMME DE TRAVAUX ........
# 2.4 CONCERTATION PREALABLE
#
# 2.5 CONCERTATION ‘FONTAINE’ POUR LE RACCORDEMENT ...
# 2.6 — ENQUETE PUBLIQUE...........
# 2.7 CONTENU DU DOSSIER D'ETUDE D'IMPACT ......
#
#
#
#
#
#
#
# 3. ANNEXE - BILAN DU GARANT DE LA CONCERTATION ..

# %%
import numpy as np

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
import matplotlib.pyplot as plt

# %%
# grayscale
gray = get_grayscale(img)
plt.imshow(gray)

# %%
custom_config = r'--oem 3 --psm 4'

# %%
print(pytesseract.image_to_string(gray,config=custom_config))
# Out:
# 4. CONTEXTE GENERAL DU PROJET.
#
#
#
# 11. LES GRANDS DEFIS ENERGETIQUES 5
# 1.2. _ LAPROGRAMMATION DU DEVELOPPEMENT DES ENERGIES RENOUVELABLES EN FRANCE 6
# 1.3. _ CONTEXTE DU PROJET PROVENCE GRAND LARGE 7
# 1.3.1. Un projet développé depuis 2011 7
# 1.3.2. L’appel a projets de 2015 (AAP) 8
#
# 2. CONTEXTE ADMINISTRATIF DU PROGRAMME DE TRAVAUX ..
#
#
#
# 2.1 PRESENTATION DES MAITRES D'OUVRAGE: 10
# 2.2 CONTEXTE REGLEMENTAIRE DE L’ETUDE D’IMPACT. 10
# 2.3 NOTION DE PROGRAMME DE TRAVAUX 12
# 24 CONCERTATION PREALABLE. 13
# 2.5 CONCERTATION ‘FONTAINE’ POUR LE RACCORDEMENT 13
# 2.6 ENQUETE PUBLIQUE 14
# 2.7 CONTENU DU DOSSIER D'ETUDE D'IMPACT 14
#
# 3. ANNEXE - BILAN DU GARANT DE LA CONCERTATION ..

# %%
# tresholding
tresh = thresholding(gray)
plt.imshow(tresh)

# %%
print(pytesseract.image_to_string(tresh))
# Out:
# 1.
#
# 3.
#
# CONTEXTE GENERAL DU PROJET.
#
#
#
# 5
# 1A. LES GRANDS DEFIS ENERGETIQUES 5
# 1.2. LAPROGRAMMATION DU DEVELOPPEMENT DES ENERGIES RENOUVELABLES EN FRANCE 6
# 1.3. _ CONTEXTE DU PROJET PROVENCE GRAND LARGE 7
#
# 1.3.4. Un projet développé depuis 2011 7
#
#
#
# 1.3.2. L’appet a projets de 2015 (AAP) 8
# CONTEXTE ADMINISTRATIF DU PROGRAMME DE TRAVAUX ..
# 2.1 PRESENTATION DES MAITRES DOUVRAGE 10
# 2.2 CONTEXTE REGLEMENTAIRE DE L'ETUDE D'IMPACT. 10
# 2.3 NOTION DE PROGRAMME DE TRAVAUX 12
# 2.4 CONCERTATION PREALABLE 13
# 2.8 CONCERTATION FONTAINE’ POUR LE RACCORDEMENT 13
# 2.6 ENQUETE PUBLIQUE 14
# 2.7 CONTENU DU DOSSIER D'ETUDE D'IMPACT 14
#
# ANNEXE - BILAN DU GARANT DE LA CONCERTATION ..

# %%
# opening

openn = opening(gray)
plt.imshow(openn)

# %%
print(pytesseract.image_to_string(openn))
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# UU — LA DU GAT Ot LA COMCETTATION
#
# QErPooCees Be eK

# %%
# canny

can = canny(gray)
plt.imshow(can)

# %%
print(pytesseract.image_to_string(can))
# Out:
# 41. GONTEXTE GENERAL BU PROJET
#
#
#
# 41.41,  Lag@Ranss cers dxencenoues
# 1.2.  LARROGRAMMATION DU DEVELOPPEMENT O58 GUERGIES RENOLVELAR
# 1.3.  Conmecre qu PRover Provence Grand LARGE ..
# 13.9. Un prgjet dgvelogpe dapuls 2017
# 122 Capper d srofels de 207 (AAP)
#
# CONTEXT ADLMINISTRATIF DU PROGRALIME DE TRAVAUR ......c0umssnuermninninnimsiniensim se 10
#
#
#
#
#
#
#
#
#
#
# Sy
#
# 2.1 PRESENTATION DES LAiTRES DIOUYRAGE.,
# 22 CONTEXTS REGLEMENTANRE 08 ETUDE DTLPACT..
# aa Ne (BE PROGRAMME DE TRAVAUK...
# 24  Concarramon eRtaal
# 25 CONCERTATION FONTAINE’ FOUR LE RACCORDSIENT,
# 26 Geovere rususve
# 2.7 — ConTénu du CossiSR O'eTUDE O'EAPACT
#
#
#
#
#
#
#
#
#
#
# 2 ANNEXE - BILAN BU GARANT OE LA
#
#
#
# NIGER TATION oo cesesumsinninsimuimstinieminmsinssiniimiin 7
