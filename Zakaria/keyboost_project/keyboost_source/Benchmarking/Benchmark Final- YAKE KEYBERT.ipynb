# %%
import  os
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### PubMed Data Wrangling

# %%
path = os.path.join('PubMed','docs_keys')

# %%
indices = set([f[:-4]  for f in os.listdir(path)])

# %%
pd.read_csv(r'{}\10933267.key'.format(path),sep='/n',header=None)
# Out:
#                           0
# 0                     Adult
# 1                   Alleles
# 2        Biological Markers
# 3           Body Mass Index
# 4   Cardiovascular Diseases
# 5                     Child
# 6          Child, Preschool
# 7             Ethnic Groups
# 8                    Female
# 9                Fibrinogen
# 10               Heart Rate
# 11                   Humans
# 12            Linear Models
# 13                     Male
# 14         Physical Fitness
# 15           Questionnaires
# 16             Risk Factors

# %%
buff =open(r'{}\10933267.txt'.format(path),mode='r')

# %%
txt = buff.read()

# %% [markdown]
# ### Metrics Definition

# %%
def precision_at_k(prediction,ground_truth,k):
    
    pak= sum([1 if  p==g else 0  for p in prediction[:k] for g in ground_truth])/k
    
    return pak

# %%
def recall_at_k(prediction,ground_truth,k):
    
    rak =  sum([1 if  p==g else 0 for g in ground_truth for p in prediction[:k]])/len(ground_truth)
    
    return rak

# %%
def f1_at_k(prediction,ground_truth,k):
    
    pak = precision_at_k(prediction,ground_truth,k)
    rak = recall_at_k(prediction,ground_truth,k)
    
    
    try:
        f1ak = 2 * (pak*rak)/(pak+rak) 
    except :
        f1ak = 0
        
    return f1ak

# %% [markdown]
# ### keyBoost test with one example

# %%
import pandas as pd
import numpy as np
from keyBoost_lib.keyBoost import *

# %% [markdown]
# ###### Stopwords

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

stopwords = nlp.Defaults.stop_words

# %%
keyboost = KeyBoost(transformers_model='distilbert-base-nli-mean-tokens')

# %%
keywords = keyboost.extract_keywords(text=txt,
                       language='en',
                       n_top=10,
                       keyphrases_ngram_max=2,
                       stopwords=stopwords,
                       consensus='statistical',
                       models=['yake','keybert'])
# Out:
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !

# %%
keywords
# Out:
# [('Plasma Fibrinogen', 8.241170639758252),
#  ('Fibrinogen Level', 6.452818330088773),
#  ('pediatric cardiology', 4.315605640589661),
#  ('department medicine', 3.883835479365052),
#  ('clinics pediatric', 3.3304989620674945),
#  ('university biomarkers', 3.1481494279580726),
#  ('cardiology department', 3.1167098531116206),
#  ('biochemistry university', 2.9008247724993153),
#  ('medicine columbia', 2.8882489425607347),
#  ('surgery coronary', 2.835849651149981)]

# %%
keywords_stat = [k[0] for k in keywords]

# %%
keywords_stat
# Out:
# ['Plasma Fibrinogen',
#  'Fibrinogen Level',
#  'pediatric cardiology',
#  'department medicine',
#  'clinics pediatric',
#  'university biomarkers',
#  'cardiology department',
#  'biochemistry university',
#  'medicine columbia',
#  'surgery coronary']

# %%
gt = list(pd.read_csv(r'{}\10933267.key'.format(path),sep='/n',header=None)[0])

# %%
gt
# Out:
# ['Adult',
#  'Alleles',
#  'Biological Markers',
#  'Body Mass Index',
#  'Cardiovascular Diseases',
#  'Child',
#  'Child, Preschool',
#  'Ethnic Groups',
#  'Female',
#  'Fibrinogen',
#  'Heart Rate',
#  'Humans',
#  'Linear Models',
#  'Male',
#  'Physical Fitness',
#  'Questionnaires',
#  'Risk Factors']

# %%
len(gt)
# Out:
# 17

# %%
f1_at_k(prediction=keywords,
       ground_truth=gt,
       k=10)
# Out:
# 0

# %%
precision_at_k(prediction=keywords,
       ground_truth=gt,
       k=10)
# Out:
# 0.0

# %%
recall_at_k(prediction=keywords,
       ground_truth=gt,
       k=10)
# Out:
# 0.0

# %%
f1_at_k(prediction=keywords_stat,
       ground_truth=gt,
       k=10)
# Out:
# 0

# %%
precision_at_k(prediction=keywords_stat,
       ground_truth=gt,
       k=10)
# Out:
# 0.0

# %%
recall_at_k(prediction=keywords_stat,
       ground_truth=gt,
       k=10)
# Out:
# 0.0

# %% [markdown]
# ### Statistical Consensus - YAKE and keyBert

# %%
import tqdm

# %%
f1s = list()

# %%
for i in tqdm.autonotebook.tqdm(indices) :
    gt = list(pd.read_csv(r'{}\{}.key'.format(path,i),sep='/n',header=None)[0])
    
    buff =open(r'{}\{}.txt'.format(path,i),mode='r')
    txt = buff.read()
    
    
    keywords = keyboost.extract_keywords(text=txt,
                       language='en',
                       n_top=10,
                       keyphrases_ngram_max=3,
                       stopwords=stopwords,
                       consensus='statistical',
                       models=['yake','keybert'])
    keywords = [k[0] for k in keywords]
    
    
    f1s.append(f1_at_k(prediction=keywords,ground_truth=gt,k=10))
    print('Current Micro Average F1@10 Score ',sum(f1s)/len(f1s))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006666666666666667
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006153846153846154
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.005714285714285714
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005333333333333333
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.004705882352941177
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0044444444444444444
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.004210526315789474
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.004
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0038095238095238095
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0036363636363636364
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0034782608695652175
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007301587301587302
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00700952380952381
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00673992673992674
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006490299823633157
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006258503401360545
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0060426929392446635
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005841269841269842
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00565284178187404
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0054761904761904765
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00531024531024531
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00515406162464986
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005006802721088436
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.004867724867724868
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.004736164736164736
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0046115288220551385
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.004493284493284493
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.004380952380952381
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006491394784077711
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006336837765409194
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006189469445283398
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006048799685163322
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005914381914381914
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0057858083945040465
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007512844848645033
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007356327247631595
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00720619812012891
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007062074157726331
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006923602115417972
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006790455920890703
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0066623341110625765
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006538957553450307
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006420067416114846
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006305423355112796
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006194801892742396
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006087994963557182
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007458647959753339
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0073343371604241165
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009946342562165799
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009785917682130867
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009630585655430377
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009480107754564277
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009334259942955597
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009192831762001724
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009055625317792743
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008922454357236967
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008793143424523387
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008667527089887338
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008545449243550898
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009815651337390468
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009681190360165941
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009550363463406942
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00942302528389485
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00929903810910676
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00917827138041706
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00906060123451428
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009919619914116337
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009795624665189883
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009674691027348033
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009556706990429155
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009441565942351696
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00932916634779989
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009219411449590478
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00911220899087431
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009628781922634997
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009519363946241418
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009412404800778032
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009307822525213831
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009205538761200492
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009105478557274399
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009007570185690804
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008911744970949412
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008817937129149946
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008726083617387966
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008636123992466441
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0085480002782576
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008461656841103482
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008377040272692447
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008294099279893512
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008212784581071027
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008133048808439269
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008054846416050431
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007978133593040426
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007902868181785329
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007829009600647148
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007756518771011526
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007685358048341695
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007615491156993134
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008404883986552612
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00832984037952982
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008256124977941062
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008183702829011754
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008112540195716
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008042604504373621
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00797386429493453
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007906289173791017
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007839849768969244
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007774517687561167
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007710265475267273
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007647066577929016
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.007584895304937724
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0075237267944140325
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00746353698005872
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007404302559582064
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007346000964624724
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007288610332088594
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007232109476801085
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007176477865441077
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007121695591659084
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007067743352328334
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.007014602424867218
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006962254645577164
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006910682388943259
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006859868547848088
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006809796514652117
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006760450163096667
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0067118138309880575
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006663872303623857
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006616610797924397
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006570014947234789
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006524070786764615
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006478764739634306
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006434083603498897
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0063900145377215065
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00634654505107034
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006303662989914459
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006261356526894899
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006219614150048933
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00617842465236649
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.006137777121758815
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006097660931420523
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006058065730567143
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.006018981435531225
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0059803982212008975
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005942306512785605
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005904696977894557
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005867560518914088
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.005830888265670875
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005794671568368571
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.005758901990786049
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0057235713037260124
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0056886714787032925
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0056541946818626666
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.005620133268116506
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0055864797754930536
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# ...
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00914749734920731
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009127033149320939
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009106660307469776
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009086378213243786
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0090661862616588
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009046083853096363
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00902607039324438
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009006145293038543
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009325176148882409
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009304681256247503
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009284276253492575
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009263960550530885
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009243733562429288
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.0092235947093521
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009203543416505682
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00918357911408376
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009351918816735378
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00933172028797353
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009311608821835658
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009291583856627409
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009405765007149666
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009385624182723222
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009365569430196036
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009345600199001589
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009325715943259032
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00930591612172345
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009286200197736747
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009266567639179164
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009247017918421403
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009227550512277357
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009208164901957448
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009188860573022525
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009169637015338378
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009150493723030782
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009131430194441134
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00911244593208263
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00909354044259698
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009074713236711687
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.00905596382919782
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00903729173882834
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009018696488336924
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.0090001776043773
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009176894648708687
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009158127992985357
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009139437935856816
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009120824009307209
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00910228574912569
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009083822694867828
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [False, True]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00906543438981749
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009047120380949172
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.009028880218890806
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.009010713457887001
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# No DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [False, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.008992619655762731
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# [True, True]
# Consolidation + Rank Extraction
# Deduplication
# Done !
# Current Micro Average F1@10 Score  0.008974598373887454
# *** statistical discriminativeness check **
# * keyword extraction model 1 *
# DSM Params OK
# KS OK
# Proper DSM behind data
# * keyword extraction model 2 *
# No DSM behind data
# [True, False]
# Fallback to Rank Based Consensus
# Current Micro Average F1@10 Score  0.00895664917713968

# %%
sum(f1s)/len(f1s)
# Out:
# 0.00895664917713968

# %% [markdown]
# ### Rank Consensus - YAKE and  keyBert

# %%
f1s = list()

# %%
for i in tqdm.autonotebook.tqdm(indices) :
    gt = list(pd.read_csv(r'{}\{}.key'.format(path,i),sep='/n',header=None)[0])
    
    buff =open(r'{}\{}.txt'.format(path,i),mode='r')
    txt = buff.read()
    
    
    keywords = keyboost.extract_keywords(text=txt,
                       language='en',
                       n_top=10,
                       keyphrases_ngram_max=3,
                       stopwords=stopwords,
                       consensus='rank',
                       models=['yake','keybert'])
    
    keywords = [k[0] for k in keywords]
    
    
    f1s.append(f1_at_k(prediction=keywords,ground_truth=gt,k=10))
    print('Current Micro Average F1@10 Score ',sum(f1s)/len(f1s))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.0
# Current Micro Average F1@10 Score  0.
# Current Micro Average F1@10 Score  0.027504365209967886
# Current Micro Average F1@10 Score  0.02745217476364916
# Current Micro Average F1@10 Score  0.027400182008414976
# Current Micro Average F1@10 Score  0.027528420029643105
# Current Micro Average F1@10 Score  0.02785383810505887
# Current Micro Average F1@10 Score  0.027801382666066292
# Current Micro Average F1@10 Score  0.02789950036782181
# Current Micro Average F1@10 Score  0.027847156089458164
# Current Micro Average F1@10 Score  0.027915824578115093

# %%
sum(f1s)/len(f1s)
# Out:
# 0.027915824578115093

# %% [markdown]
# ## keyBert

# %%
from keybert import *

# %%
f1s = list()

# %%
for i in tqdm.autonotebook.tqdm(indices) :
    gt = list(pd.read_csv(r'{}\{}.key'.format(path,i),sep='/n',header=None)[0])
    
    buff =open(r'{}\{}.txt'.format(path,i),mode='r')
    txt = buff.read()
    
    kb = KeyBERT('distilbert-base-nli-mean-tokens')

    keywords = kb.extract_keywords(txt,
                                      keyphrase_ngram_range = (1,3),
                                      top_n = 10,
                                      stop_words=stopwords)
    
    keywords = [k[0] for k in keywords]
    
    print(keywords)
    
    f1s.append(f1_at_k(prediction=keywords,ground_truth=gt,k=10))
    
    print('Current Micro Average F1@10 Score ',sum(f1s)/len(f1s))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ['petals chlorophyll degraded', 'lipid metabolism removed', 'lipoxygenase lox senescence', 'decline lipid occurs', 'remobilization nutrients floral', 'photooxidation lipids loss', 'studies extraction lipids', 'cycle detoxifying enzymes', 'antioxidants decline sepals', 'lipids loss chlorophyll']
# Current Micro Average F1@10 Score  0.0
# ['ideal pcr amplification', 'efficiency cdna synthesis', 'pcr efficiency significantly', 'doubling dna pcr', 'similar pcr amplification', 'kinetics valid pcr', 'pcr reliable method', 'cdna synthesis improve', 'efficiencies pcr reactions', 'slope ideal pcr']
# Current Micro Average F1@10 Score  0.0
# ['peanut genomic dna', 'family kinases peanut', 'isolated peanut seedlings', 'kinase peanut protein', 'immunohistochemistry microscopy peanut', 'dna isolated peanut', 'genes peanut seedlings', 'peanut sty kinase', 'specificity kinase peanut', 'gene genome peanut']
# Current Micro Average F1@10 Score  0.0
# ['antibiotic pharmacodynamics surgical', 'antibiotic surgery duration', 'antibiotic exposure surgery', 'information antibiotic pharmacodynamics', 'antibiotic concentrations postoperative', 'antibiotic prolonged surgery', 'antibiotic surgery', 'preoperative antibiotic surgery', 'antibiotic pharmacodynamics', 'preselected targeted antibiotic']
# Current Micro Average F1@10 Score  0.0
# ['recombination defective cells', 'dna damage mutations', 'cytotoxic dna lesion', 'different dna damaging', 'critical dna lesion', 'damage mutations genes', 'mutations genes render', 'cells bearing mutations', 'dna damaging agents', 'damaged dna authors']
# Current Micro Average F1@10 Score  0.0
# ['pcr assays dna', 'atcc 10557 streptococcus', 'microliters dna samples', 'pcr oral treponemes', '10557 streptococcus salivarius', 'genomic blood dna', 'pcr assay clinical', 'assays measured dna', 'mutans gs5 streptococcus', 'gs5 streptococcus oralis']
# Current Micro Average F1@10 Score  0.0
# ['contact outpatient clinic', 'consultation outpatient clinic', 'outpatient clinic spontaneous', 'outpatient clinic cohort', 'start consultation outpatient', 'patients start consultation', 'patients outpatient clinic', 'clinic cohort study', 'consent patients doctors', 'outpatient clinic department']
# Current Micro Average F1@10 Score  0.0
# ['densitometry autoradiograms dna', 'algorithm searching dna', 'searching dna sequences', 'scanning dna sequences', 'dna sequences discriminate', 'assays transcription dna', 'algorithms dna binding', 'analysis scanning dna', 'dna sequences experimental', 'hnf1 binding dna']
# Current Micro Average F1@10 Score  0.0
# ['backtracking rna polymerase', 'enzyme backtracks dna', 'dna hybrid backtracking', 'polymerase backtracking rnap', 'backtracks dna template', 'experiments dna biotinylated', 'second translocates dna', 'involves backtracking enzyme', 'polymerase translocates dna', 'dna undergoes overstretching']
# Current Micro Average F1@10 Score  0.0
# ['performance improved sleep', 'improved sleep trained', 'training proper sleep', 'sleep practice enhanced', 'recovery sleep indicating', 'experiments sufficiently slept', 'improving effects sleep', 'enhanced sleep skill', 'night recovery sleep', 'interval slept regularly']
# Current Micro Average F1@10 Score  0.0
# ['dt104 strains salmonella', 'genes salmonella genomic', 'strains tested salmonella', 'tested salmonella genomic', 'resistance genes salmonella', 'multidrug resistant salmonella', 'salmonella strains transduction', 'salmonella strain multidrug', 'salmonella genomic', 'genes salmonella']
# Current Micro Average F1@10 Score  0.0
# ['maize mapping chromosomal', 'wheat glutathione transferase', 'hexaploid wheat glutathione', 'analysis wheat genome', 'genomes cultivated hexaploid', 'genome hexaploid wheat', 'wheat gst genes', 'finding rice genes', 'diploid wheat genome', 'wheat genomes sequence']
# Current Micro Average F1@10 Score  0.0
# ['recovery mycobacteria tuberculosis', 'value mycobacterium tuberculosis', 'tuberculosis detection fluorescence', 'improvement recovery mycobacteria', 'tuberculosis smear sensitivity', 'processing anti tb', 'tuberculosis tb diagnosis', 'increasing tuberculosis smear', 'techniques tuberculosis detection', 'specimens increasing tuberculosis']
# Current Micro Average F1@10 Score  0.0
# ['thiogalactopyranose recombinant protein', 'asymmetry transgenic mice', 'immunoblotting mouse monoclonal', 'stain recombinant protein', 'generated polyclonal antibodies', 'mouse monoclonal antibodies', 'preincubated immunizing recombinant', 'biogenesis gene transcription', 'phenotype transgenic mice', 'immunizing recombinant protein']
# Current Micro Average F1@10 Score  0.0
# ['computers prompt doctor', 'hospital emails send', 'counseling prompting physicians', 'computers installed patient', 'emails send hospital', 'health interview survey', 'patient acceptance computerized', 'data obtained patients', 'computer visit doctor', 'computerized prompts patient']
# Current Micro Average F1@10 Score  0.0
# ['evolution dna shuffling', 'vitro evolution dna', 'dna shuffling resulted', 'power dna shuffling', 'dna shuffling technique', 'predicting evolution vitro', 'dna shuffling stemmer', 'dna shuffling methods', 'evolution dna', 'substitutions dna shuffling']
# Current Micro Average F1@10 Score  0.0
# ['drosophila recq5 homolog', 'drosophila melanogaster recq5', 'results drosophila genome', 'protein isolated drosophila', 'drosophila genome project', 'isolated drosophila recq5', 'gmppnp activated dna', 'gtp binding drosophila', 'drosophila genome', 'drosophila recq5']
# Current Micro Average F1@10 Score  0.0
# ['pharyngitis pneumonia common', 'patients causing pneumonia', 'pneumonia tracheobronchitis abscess', 'dogmatis common pathogens', 'pneumonia common manifestation', 'causing pneumonia patients', 'immunoglobulin deficiency frequently', 'septica common pathogens', 'mild form pneumonia', 'pneumonia common']
# Current Micro Average F1@10 Score  0.0
# ['protein dna key', 'oligodeoxynucleotides protein dna', 'enhancement dna binding', 'affinity dna recognition', 'novel gene therapy', 'dna plasmids encoding', 'affinity enzyme dna', 'complexed dna cofactor', 'dna methylation enzymes', 'induced packaging dna']
# Current Micro Average F1@10 Score  0.0
# ['cdcdr1 mutation vivo', 'cd57 fluconazole resistant', 'cdcdr1 mrna fluconazole', 'nonsense mutation cdcdr1', 'cdcdr1 gene 92', 'cd57 cdcdr1 gene', 'strains cd57rm4 cdcdr1delta', 'kda truncated cdcdr1p', 'overexpressed cdcdr1 cdmdr1', 'cd57r cdr1 mutant']
# Current Micro Average F1@10 Score  0.0
# ['sheep homozygous prpmarq', 'japan sheep scrapie', 'sheep scrapie japan', 'sheep homozygous', 'sheep scrapie infections', 'nontransmissible mice suggesting', 'genome date prevents', 'occurring sheep homozygous', 'nontransmissible icr mice', 'isolates experimental sheep']
# Current Micro Average F1@10 Score  0.0
# ['challenge annotating genomes', 'challenge postgenome sequencing', 'algorithm calculates dna', 'performing genome analyses', 'annotating genomes higher', 'interested performing genome', 'dnase footprinting electromobility', 'calculates maximum dna', 'shifting dna window', 'analyze large genomic']
# Current Micro Average F1@10 Score  0.0
# ['pmg1 plasmid dnas', 'dna plasmids isolated', 'pcr amplification dna', 'plasmid dnas isolated', 'enterococcus strains grown', 'gentamicin ampicillin 640', 'enterococcus strains bacteria', 'pcr analysis ninety', 'ampicillin 640 isolates', 'plasmid dnas studied']
# Current Micro Average F1@10 Score  0.0
# ['rats divided rats', 'hemofiltration rats undergone', 'sem found rats', 'rats undergone cecal', 'state rats sepsis', 'sprague dawley rats', 'rats cecal ligation', 'dawley rats divided', 'rats sepsis manner', 'hemofiltration rats']
# Current Micro Average F1@10 Score  0.0
# ['acids suppress immune', 'immune functions damaged', 'diseases unsaturated fatty', 'immune system reducing', 'apoptosis suppressing bcl', 'dietary lipids reduction', 'impaired bacterial clearance', 'impair cellular immunity', 'immune system reduction', 'diet infected monocytogenes']
# Current Micro Average F1@10 Score  0.0
# ['dehydrogenase sequence sav0542', 'threonine dehydrogenase proteins', 'mammalian threonine dehydrogenases', 'mammalian threonine dehydrogenase', 'threonine dehydrogenase genes', 'threonine dehydrogenase protein', 'threonine dehydrogenase primers', 'dehydrogenase genes mammalian', 'threonine dehydrogenase mrna', 'dehydrogenase cdna cloned']
# Current Micro Average F1@10 Score  0.0
# ['5b gene sequencing', 'hepatitis virus genotyping', 'virus genotyping interrogation', 'discrepancy sequenced dna', 'polymorphism hcv genome', 'hcv genome determination', 'virus hcv genome', 'hcv genome isolates', '5b gene data', 'investigate dna sequencing']
# Current Micro Average F1@10 Score  0.0
# ['ethanol rats impaired', 'rats exposed ethanol', 'ethanol neonates neonatal', 'ethanol exposed rats', 'deficits adult rats', 'ethanol neonates impaired', 'neonatal binge ethanol', 'ethanol neonates disrupted', 'rats damage cerebellar', 'adult rats neonatal']
# Current Micro Average F1@10 Score  0.0
# ['prevent pressure necrosis', 'neurologic injury poor', 'replacement therapy safety', 'pressure necrosis inadvertent', 'renal replacement therapy', 'skin pressure necrosis', 'therapy prone positioning', 'potential cannula complications', 'therapy crrt benefit', 'cannula complications including']
# Current Micro Average F1@10 Score  0.0
# ['proteins phylogenetic analysis', 'protein bacterium novosphingobium', 'search bacterial genomes', 'protein template information', 'hfq sequences bacteria', 'bacterial genomes examined', 'bacterial genomes available', 'hfq protein bacteria', 'searches bacterial genomes', 'protein structures database']
# Current Micro Average F1@10 Score  0.0
# ['pesticides repression fungal', 'hemibiotrophic fungus crinipellis', 'phytopathogenic fungus perniciosa', 'phytopathogenic fungus', 'cocoa plant witches', 'caused hemibiotrophic fungus', 'pathogen antagonism antibiotics', 'broom disease fungal', 'fungus crinipellis perniciosa', 'disease fungal strain']
# Current Micro Average F1@10 Score  0.0
# ['insulin resistance sleep', 'diabetes epidemiology collaborative', 'diabetes sleep disturbances', 'policemen study diabetes', 'libby diabetes atherosclerosis', 'health study diabetes', 'diabetes atherosclerosis epidemiology', 'al diabetes sleep', 'group diabetes epidemiology', 'epidemiology group diabetes']
# Current Micro Average F1@10 Score  0.0
# ['drug sparsogenes dna', 'antibiotic resistance dna', 'antitumor antibiotic sparsomycin', 'ribosomes aminoglycoside antibiotic', 'sparsogenes dna curing', 'antibiotic bind nucleotide', 'sparsomycin curing plasmid', 'dna curing plasmid', 'antibiotic producing streptomycetes', 'antibiotic sparsomycin']
# Current Micro Average F1@10 Score  0.0
# ['hemodynamically centered therapy', 'infusion studied sepsis', 'studies sepsis improvements', 'disease hemodynamic resuscitation', 'saline resuscitation sepsis', 'sepsis improvements myocardial', 'ischemia reperfusion hand', 'restored microcirculatory blood', 'improved hemodynamic profile', 'immunomodulation sepsis rivers']
# Current Micro Average F1@10 Score  0.0
# ['mice induction antivirus', 'antiviral drug interferons', 'emcv infection inhibited', 'mhv infection vivo', 'antiviral drugs ribavirin', 'protein inhibits virus', 'viruses cytokines encephalomyocarditis', 'encephalomyocarditis virus herpes', 'apoptosis antiviral activity', 'inducing apoptosis antiviral']
# Current Micro Average F1@10 Score  0.0
# ['pcr fingerprinting dna', 'fingerprinting dna isolate', 'phenotypic assays serotyping', 'pcr fingerprinting clusters', 'bacteriocin typing biotyping', 'multiple genomic typing', 'fingerprinting set 97', 'geldoc2000 gel analyzer', 'guidelines interpreting dna', 'pcr fingerprinting mlrt']
# Current Micro Average F1@10 Score  0.0
# ['genes streptococcus intermedius', 'streptococcus sanguis streptococcus', 'groesl genes streptococcus', 'streptococcus anginosus streptococcus', 'includes streptococcus anginosus', 'dnas streptococcal species', 'streptococcus intermedius streptococcus', 'streptococcus parasanguis streptococcus', 'streptococcus mutans streptococcus', 'streptococcus pyogenes 632']
# Current Micro Average F1@10 Score  0.0
# ['disease epidemiology methodological', 'flaws measurement medical', 'clinical medicine variations', 'identification patients disease', 'clinical research mismeasure', 'chronic disease epidemiology', 'research mismeasure patient', 'disease epidemiological model', 'guidelines clinical medicine', 'chronic disease epidemiological']
# Current Micro Average F1@10 Score  0.0
# ['uvr8 mutation confirming', 'uv mediated dna', 'dna repair uvr1', 'uvr8 mutation indication', 'genetic mapping mutation', 'seed dna extraction', 'studies arabidopsis mutants', 'rcc1 mutations fungi', 'pcr dna thermal', 'genetic analysis uvr8']
# Current Micro Average F1@10 Score  0.0
# ['alternative biomedical domains', 'warehousing biomedical data', 'databases alternative biomedical', 'consideration warehousing biomedical', 'clinical microbiology data', 'methods clinical microbiology', 'heterogeneous biomedical data', 'query involves antimicrobial_tested', 'organism quantity_cultured antimicrobial_tested', 'clinical medicine']
# Current Micro Average F1@10 Score  0.0
# ['repress lhc genes', 'lhcb4 mrnas reinhardtii', 'reduces lhc mrna', 'lhc mrnas repressed', 'lhc genes redox', 'lhcb4 lhcb5 mrnas', 'repressed lhc mrnas', 'reinhardtii cells photoautotrophically', 'repressing lhc mrnas', 'repress lhc mrnas']
# Current Micro Average F1@10 Score  0.0
# ['808 blood donors', 'retested 400 serum', 'collected 808 donors', 'infections 808 blood', 'million blood donations', 'ghana thirty donors', 'ghanaian blood donation', 'female 762 donors', 'blood donations worldwide', '808 donors labeled']
# Current Micro Average F1@10 Score  0.0
# ['decreased levels dehydroepiandrosterone', 'adrenal insufficiency dehydroepiandrosterone', 'illness dopamine dosage', 'adrenal axis sepsis', 'dehydroepiandrosterone sulphate severe', 'cortisol tumour necrosis', 'adrenal hpa hypofunction', 'critical illness adrenal', 'immunostimulating antiglucocorticoid effects', 'hormones immunostimulating antiglucocorticoid']
# Current Micro Average F1@10 Score  0.0
# ['waxy barley cultivars', 'amylose barley cultivars', 'waxy cultivars barley', 'amylose cultivars barley', 'barley cultivars cloned', 'cultivars barley hordeum', 'cultivars barley protein', 'waxy barley endosperms', 'barley cultivars physicochemical', 'barley cultivars sequenced']
# Current Micro Average F1@10 Score  0.0
# ['hypothesis testing present', 'tests exist examine', 'statistical tests exist', 'case sample test', 'statistics review comparison', 'statistic paired test', 'hypothesis test case', 'tests discussed comparison', 'intervals hypothesis testing', 'hypothesis test standard']
# Current Micro Average F1@10 Score  0.0
# ['mitochondria isolated glyb', 'mitochondria isolated lymphoblasts', 'mitochondria shown thiamine', 'mitochondria convert thiamine', 'mitochondria demonstrated thiamine', 'mitochondria uptake thiamine', 'lymphoblasts mitochondria isolated', 'lymphoblasts found thiamine', 'rat liver mitochondria', 'penicillin streptomycin glyb']
# Current Micro Average F1@10 Score  0.0
# ['genes prokaryotic genomes', 'yeast spt16p cdc68p', 'sequenced eukaryotic genomes', 'orthologue yeast spt16p', 'eukaryotic genomes sequenced', 'orthologues yeast spt4p', 'sequenced genomes investigated', 'dna assembling rna', 'yeast spt4p spt5p', 'drosophila melanogaster ld12377p']
# Current Micro Average F1@10 Score  0.0
# ['medicine transdisciplinary study', 'technologies medicine insufficient', 'new technologies medicine', 'technologies medicine transdisciplinary', 'new technologies cancer', 'medicine transdisciplinary', 'institute medicine panel', 'technologies medicine', 'health research physicians', 'efficiency institute medicine']
# Current Micro Average F1@10 Score  0.0
# ['atpases required protein', 'mouse atp10c homolog', 'genes drs2delta dnf1delta', 'drs2p dnf1p protein', 'drs2 dnf genes', 'genome contains genes', 'atpases potential aminophospholipid', 'pygw1 geneweaver kit', 'drs2 neo1 genes', 'drs2p dnfs protein']
# Current Micro Average F1@10 Score  0.0
# ['resistance salmonellae mainly', 'resistant salmonellae wild', 'salmonellaenterica serotype typhimurium', 'quinolone resistance salmonellae', 'mutation described salmonella', 'salmonella serotype typhimurium', 'salmonella specific primers', 'acid resistant salmonellae', 'salmonellae mainly associated', 'resistant isolates salmonellae']
# Current Micro Average F1@10 Score  0.0
# ['antibiotics setting challenging', 'complex intervention antibiotic', 'complex health interventions', 'challenging diagnosis infection', 'trial optimize antibiotic', 'antibiotic trial involved', 'complex health intervention', 'physicians developing algorithms', 'prescribing antibiotics asymptomatic', 'trial improve antibiotic']
# Current Micro Average F1@10 Score  0.0
# ['dna dna crystallization', 'dna crystallization finding', 'dna crystallization facilitated', 'facile crystallization dna', 'spermine dna crystallization', 'dna crystallization', 'cases dna crystallization', 'crystalline transformation dna', 'dna polarizing microscopy', 'crystallization dna']
# Current Micro Average F1@10 Score  0.0
# ['dermatophyte infections especially', 'dermatitis patients immunosuppressive', 'inflammatory skin disease', 'skin diseases chronic', 'dermatophyte infection severe', 'allergies fungal infections', 'dermatophyte infections common', 'dermatitis ad chronic', 'chronic dermatophyte infections', 'patient rhinitis asthma']
# Current Micro Average F1@10 Score  0.0
# ['cytokines frequent proinflammatory', 'cytokines affect infectious', 'cytokine frequently proinflammatory', 'lymphocytes spontaneously making', 'cytokines fibroblasts neutrophils', 'lymphocytes spontaneously producing', 'fluorescent staining cytokine', 'cytokines regulate cellular', 'frequently proinflammatory cytokine', 'patients immune studies']
# Current Micro Average F1@10 Score  0.0
# ['splenocytes immunized mice', 'immunoblotting mouse polyclonal', 'bacteria detected antibodies', 'immunized mice sp2', 'prowazekii immunoblotting mouse', 'ag14 myeloma cells', 'haemophilus influenzae streptococcus', 'mice inoculated intraperitoneally', 'myeloma cells immunoblotting', 'sp2 ag14 myeloma']
# Current Micro Average F1@10 Score  0.0
# ['mycobacterium tuberculosis majority', 'mycobacterium tuberculosis vitro', 'bactericidal vitro tuberculosis', 'bactericidal tuberculosis vitro', 'tested mycobacterium strains', 'mycobacterium tuberculosis cb3', 'h37ra isolates mycobacterium', 'demonstrated vitro antimycobacterial', 'tuberculosis bacteriostatic vitro', 'isolates mycobacterium tuberculosis']
# Current Micro Average F1@10 Score  0.0
# ['mouse gene 1700013g23rik', 'genes overlapping dkfzp586m1120', 'genes flj10193 dkfzp586m1120', 'patients deletions 17p11', 'transcripts kiaa1820 dkfzp434a139', 'mouse genes homologous', 'dkfzp434a139 mouse rai1', 'flj10193 exon gene', 'genes mapped 17p11', 'cmt1a hereditary neuropathy']
# Current Micro Average F1@10 Score  0.0
# ['thirty questionnaires returned', 'second email fax', '2001 doctors piehl', 'reviews absence funding', '2001 doctors', 'training program abstract', 'workshops 1998 2000', 'qualitative comments email', 'december 2001 doctors', '2000 workshop participants']
# Current Micro Average F1@10 Score  0.0
# ['drug tested yeast', 'yeast assay vitro', 'tested yeast growth', 'development yeast assay', 'gene yeast transformed', 'inhibitors obtained yeast', 'yeast penetration drug', 'drugs demonstrated yeast', 'yeast complementation assay', 'demonstrated yeast assay']
# Current Micro Average F1@10 Score  0.0
# ['alleles human genome', 'gene sets bioinformatics', 'human genome disease', 'genome scanning advantage', 'nssnps human genes', 'coding snps discovery', 'synonymous coding snps', 'mutations explain molecular', 'genes frequently enzymes', 'sets bioinformatics expertise']
# Current Micro Average F1@10 Score  0.0
# ['biosynthesis catalyzed homospermidine', 'pa biosynthesis homospermidine', 'biosynthesis homospermidine synthase', 'seedlings developed cotyledons', 'biosynthesis resulting homospermidine', 'biosynthesis hyoscyamine 6beta', 'ancestor deoxyhypusine synthase', 'biosynthesis homospermidine pathway', 'plumbaginifolia corresponding genes', 'eukaryotes archaebacteria recently']
# Current Micro Average F1@10 Score  0.0
# ['0826 streptococcus pneumoniae', 'streptococcus pneumoniae pharmacodynamic', 'cephalosporins compared bacterial', 'streptococcus pneumoniae strains', 'sixteen pneumoniae isolates', 'mice bacterial inoculation', 'clinical isolates pneumoniae', 'pneumoniae pharmacodynamic assessment', 'pneumoniae test isolates', 'ertapenem pneumoniae isolates']
# Current Micro Average F1@10 Score  0.0
# ['people require transplant', 'patients orchestrate dying', 'organ transplants continue', 'waiting brain death', 'anticipation organ donation', 'require transplant united', 'anticipation brain death', 'death organ donation', 'hospital nearly drowning', 'require transplant']
# Current Micro Average F1@10 Score  0.0
# ['antibodies selective phytochrome', 'gels normalized dna', 'gel normalized dna', 'seedlings dna content', 'antibodies purity proteins', 'flowers protein dna', 'phytochromes monoclonal antibodies', 'performed normalized dna', 'immunoblotted leaves inflorescence', 'growth showed dna']
# Current Micro Average F1@10 Score  0.0
# ['endonuclease cleaved dna', 'dna cleavage endonucleases', 'endonucleases target dna', 'mutations alter dna', 'studying repair dna', 'endonuclease induced dna', 'examine dna cleavage', 'predicted protein dna', 'analysis plasmid dnas', 'assays analyze dna']
# Current Micro Average F1@10 Score  0.0
# ['hisactophilin involved osmoprotection', 'electrophoresis preparation cytoskeletal', 'polymerization vitro cells', 'proteins gel electrophoresis', 'geneticin hyperosmotic shock', 'cells osmosensitive hisactophilin', 'shock hisactophilin immunoprecipitated', 'shock actin phosphorylation', 'stress immunoprecipitated hisactophilin', 'autoradiography fluorescence microscopy']
# Current Micro Average F1@10 Score  0.0
# ['readmissions frequent outpatient', 'twice patients dr', 'frequent outpatient clinic', 'reviewed twice patients', 'saw twice patients', 'physician hospital outpatient', 'patients admitted emergency', 'patients followed outpatients', 'physicians different outpatient', 'outpatient clinic follow']
# Current Micro Average F1@10 Score  0.0
# ['peptostreptococcus sp arcanobacterium', 'actinomyces novel bacterium', 'peptostreptococcus micros peptostreptococcus', 'profile novel bacterium', 'novel bacterium possess', 'sources novel bacterium', 'novel bacterium forms', 'streptococcus sp strain', 'micros peptostreptococcus sp', 'lenta microaerophilic streptococcus']
# Current Micro Average F1@10 Score  0.0
# ['100 hsv herpes', 'hsv antibodies available', 'results 128 pediatric', 'herpeselect hsv elisa', 'patients herpeselect elisa', 'antibodies hsv pediatric', 'elisas tests pediatric', 'detecting antibodies herpes', 'sensitivity 100 herpes', 'immunoassays detecting antibodies']
# Current Micro Average F1@10 Score  0.0
# ['spectrum phosphodiesterase inhibitor', 'phosphodiesterase inhibitor variation', 'tyrosine kinases regulates', 'kinase pkg inhibitors', 'kinases regulates sgc', 'phosphodiesterase inhibitor ibmx', 'nitrosylation cysteine tyrosine', 'chromaffin cells kinases', 'phosphodiesterase inhibitor', 'activation tyrosine kinases']
# Current Micro Average F1@10 Score  0.0
# ['s165v fluorescent mutants', 'fluorescent proteins mutagenesis', 'ascp fluorescent mutants', 'fluorescent mutants ascp', 'fluorescent random mutagenesis', 'color anthozoa proteins', 'ascp chromoprotein mutations', 'green fluorescent protein', 'fluorescent chromoproteins cps', 'green emitting mutants']
# Current Micro Average F1@10 Score  0.0
# ['herpesviruses transcriptional activator', 'herpesvirus transcriptional activator', 'herpesviruses transcriptional', 'herpesvirus transcriptional', 'common herpesviruses transcriptional', 'gammaherpesviruses encode rta', 'herpesvirus putative transactivator', 'herpesvirus hhv encodes', 'rta common herpesviruses', 'herpesvirus hhv discovered']
# Current Micro Average F1@10 Score  0.0
# ['treating herpesvirus infections', 'pcv treating herpesvirus', 'isolates immunocompetent patients', 'herpes labialis antiherpesvirus', 'treating herpesvirus', 'labialis antiherpesvirus agent', 'pcv treatment isolate', 'virus isolates patients', 'hsv isolates immunocompetent', 'antiherpesvirus agent penciclovir']
# Current Micro Average F1@10 Score  0.0
# ['002 patients autoimmune', 'lymphocytes examined cd4', 'hypoplasia predisposition autoimmune', 'thymic hypoplasia immunodeficiency', 'cells autoimmune disease', 'patients chromosome 22q11', 'cd25 cells markedly', 'infants chromosome 22q11', 'predisposition autoimmune disease', 'cells 33 healthy']
# Current Micro Average F1@10 Score  0.0
# ['dna pcr mix', 'dna prefiltration cts', 'reproducible assessment bacterial', 'template dna pcr', 'bacterial genome facilitates', 'dna polymerase filtration', 'laboratories performing bacterial', 'performing bacterial identification', 'bacterial identification assays', 'purified dna assay']
# Current Micro Average F1@10 Score  0.0
# ['genes detected salmonella', 'plasmid salmonellaenterica serotype', 'salmonellaenterica serotype typhimurium', 'dna detection salmonella', 'salmonella virulence plasmid', 'spvc salmonella plasmid', 'transferable plasmid salmonella', 'stvr2 carrying salmonellaenterica', 'plasmid salmonella enterica', 'plasmid salmonellaenterica']
# Current Micro Average F1@10 Score  0.0
# ['drosophila taf230 yeast', 'inducible yeast genes', 'yeast drosophila transcription', 'protein tra1 yeast', 'yeast transcription genes', 'tra1 yeast homolog', 'yeast proteins implicated', 'addition yeast drosophila', 'yeast spt7 including', 'coactivator complex yeast']
# Current Micro Average F1@10 Score  0.0
# ['ticks collected 400', 'ticks examined dna', 'dna ticks collected', 'examined dna ticks', 'ticks collected 165', 'dna found ticks', '2000 dna extraction', '233 ticks collected', 'blekinge stockholm dna', 'ticks collected 15']
# Current Micro Average F1@10 Score  0.0
# ['papillomatous digital dermatitis', 'lesion biopsies evidence', 'lesion biopsies useful', 'digital dermatitis hairy', 'dermatitis associated treponema', 'punch biopsies lesions', 'correlate invasive disease', 'pooled lesion biopsies', 'digital dermatitis associated', 'pdd lesion biopsies']
# Current Micro Average F1@10 Score  0.0
# ['screening tick dna', 'ticks dna samples', 'microplus ticks dna', 'tibet dna samples', 'dna samples ticks', 'tick dna specimens', 'primers tick dna', 'assays dna sequencing', 'microplus tibet dna', 'pcr screening tick']
# Current Micro Average F1@10 Score  0.0
# ['inoculated 102 trichomonads', 'staining 91 samples', '889 vaginal samples', 'laboratory diagnosis vaginalis', 'inocula 101 trichomonads', 'samples positive vaginalis', 'ml penicillin streptomycin', '202 infections symptomatic', 'laboratory broth culture', 'gold standard diagnosis']
# Current Micro Average F1@10 Score  0.0
# ['embryo development treatments', 'development treatment embryos', 'controlling embryo development', 'embryo development treatment', 'control embryo development', 'examined culturing embryos', 'embryo development effects', 'embryos altered rhizoid', 'developing embryos distichus', 'treatment embryos exogenous']
# Current Micro Average F1@10 Score  0.0
# ['analysis recombinant adenovirus', 'tested recombinant adenoviruses', 'preparation recombinant adenoviruses', 'transcription recombinant adenovirus', 'cytomegalovirus polylinker cloning', 'adenovirus dna sequences', 'adenovirus type recombinant', 'miep recombinant adenoviruses', 'cytomegalovirus miep recombinant', 'recombinant adenoviruses constructed']
# Current Micro Average F1@10 Score  0.0
# ['981 patients tuberculosis', 'conducted tuberculosis chemotherapy', 'tuberculosis 488 patients', 'patient diagnosed tb', 'tuberculosis chemotherapy', 'tuberculosis chemotherapy centre', 'smears discontinuing tuberculosis', 'study conducted tuberculosis', 'necessary discontinuing tuberculosis', 'detecting tb study']
# Current Micro Average F1@10 Score  0.0
# ['hexosaminidase cells loss', 'rundown exocytosis mast', 'retard rundown exocytosis', 'replacing endogenous protein', 'disruption allows exocytosis', 'cells loss secretory', 'forming toxin streptolysin', 'cells leak cytosolic', 'purified antibody inhibits', 'pexp17 kiaa0193 overexpression']
# Current Micro Average F1@10 Score  0.0
# ['transgenic mice overexpressing', 'tg2576 mice overexpress', 'mice overexpress swedish', 'deficits transgenic mice', 'transgenic mice overexpress', 'tg2576 mice hypersensitive', 'tg2576 mice impaired', 'amygdala transgenic mice', 'alzheimer disease neuropathology', 'mouse model alzheimer']
# Current Micro Average F1@10 Score  0.0
# ['arabidopsis tissues immunocytochemistry', 'arabidopsis tissue samples', 'arabidopsis leaf ontogeny', 'arabidopsis tissues studying', 'phyllotaxis organogenesis plant', 'leaf development arabidopsis', 'immunolocalization leaf primordia', 'structural proteins arabidopsis', 'arabidopsis seedlings node', 'arabidopsis seedlings found']
# Current Micro Average F1@10 Score  0.0
# ['coxiella burnetii immunoglobulin', 'elisas detected antibodies', 'combined prevaccination antibody', 'immunosorbent assay elisa', 'fluorescent antibody test', 'immunoglobulin igg elisa', 'immunoglobulin igg antibodies', 'burnetii specific immunoglobulin', 'serological tests antibodies', 'test reaction antibody']
# Current Micro Average F1@10 Score  0.0
# ['immunocompromised individuals cancer', 'suppressed viral dna', 'extracts chinese herbs', 'suppressed hsv dna', 'arresting hsv dna', 'reduction dna polymerase', 'denatured salmon sperm', 'chinese herbs herpes', '10 chinese herbs', 'reduction virus replication']
# Current Micro Average F1@10 Score  0.0
# ['reoviruses infect l929', 'coxsackievirus adenovirus receptor', 'jam1 coxsackievirus adenovirus', 'coxsackievirus adenovirus', 'antibodies inhibit reovirus', 'reovirus infection cellular', 'reovirus induced myocarditis', 'apoptosis reovirus infected', 'apoptosis reovirus infection', 't3 reoviruses infect']
# Current Micro Average F1@10 Score  0.0
# ['viruses overexpression atpase', 'containing viruses overexpression', 'monkey virus mpmv', 'viruses contain mutated', 'pfizer monkey virus', 'monkey virus pppy', 'mutation pronounced virus', 'viruses overexpression', 'exchangeable retroviruses viruses', 'virus recovered ultracentrifugation']
# Current Micro Average F1@10 Score  0.0
# ['dideoxynucleotide technology dna', 'technology dna sequencing', 'ehrlichial genomic dna', 'examined dna platys', 'assay platys dna', 'platys dna analyzed', 'amplify platys dna', 'dna sequencing reactions', 'molecular tools phylogenetic', 'genomic dna digested']
# Current Micro Average F1@10 Score  0.0
# ['nutrition harvard school', 'department nutrition harvard', 'diet mitochondria parkinson', 'nutrition harvard', 'harvard university food', 'ascherio1 department nutrition', 'parkinson disease dietary', 'mitochondria parkinson disease', 'women hospital harvard', 'diet parkinson disease']
# Current Micro Average F1@10 Score  0.0
# ['serum samples cytomegalovirus', 'bacteremia detectable antibodies', 'samples cytomegalovirus patients', 'samples tested antibodies', 'immunofluorescence immunoglobulins bartonella', 'patients test antibodies', 'henselae antibodies pcr', 'immunofluorescence assays serum', 'fluorescent antibody tests', 'tests detect immunoglobulin']
# Current Micro Average F1@10 Score  0.0
# ['loss greening hema1', 'decline mrna accumulation', 'loss nuclear gene', 'loss hema1 promoter', 'test decline mrna', 'synthesis loss greening', 'deregulation tetrapyrrole synthesis', 'cytokinin phya mutation', 'deregulation tetrapyrrole pathway', 'reduced lhcb expression']
# Current Micro Average F1@10 Score  0.0
# ['endogenous irf7 protein', 'protein irf7 cloned', 'protein recombination signal', 'irf7 phosphorylation nuclear', 'cellular protein recombination', 'regulates irf7 protein', 'binding irf7 protein', 'irf7 regulate viral', 'lmp1 regulated virus', 'irf7 phosphorylation involved']
# Current Micro Average F1@10 Score  0.0
# ['sheep retrovirus proviral', 'jaagsiekte sheep retrovirus', 'sheep retrovirus jsrv', 'enjsrv proviruses sheep', 'proviruses sheep goat', 'sheep retrovirus', 'proviruses sheep genome', 'distribution proviruses sheep', 'sheep genomic dna', 'adenocarcinoma sheep sheep']
# Current Micro Average F1@10 Score  0.0
# ['ser83trp changed dna', 'mutation causing ser740trp', 'changed dna cleavage', 'mutation causing thr744pro', 'mutations alpha4 helix', 'ciprofloxacin dna cleavage', 'substitution changed dna', 'dna cleavage ser740trp', 'proposed dna breakage', 'mitoxantrone dna cleavage']
# Current Micro Average F1@10 Score  0.0
# ['calcium regulates dynein', 'dynein calcium role', 'calcium regulating dynein', 'mutants function calcium', 'flagellar dynein calcium', 'calcium regulation microtubule', 'calcium modulates dynein', 'calcium alters dynein', 'calcium modulating dynein', 'microcystin inhibit calcium']
# Current Micro Average F1@10 Score  0.0
# ['hiv polymerases double', 'selective inhibitor hepadnavirus', 'hbvs mutations vitro', 'novel phosphonomethoxyethylpurine derivative', 'hepadnavirus polymerase drug', 'resistant hbv mutants', 'novel nucleotide analogue', 'hiv replication rapid', 'hbv genome antiviral', 'inhibitor hepadnavirus polymerase']
# Current Micro Average F1@10 Score  0.0
# ['studied bifidobacterium gardnerella', '92 clinical strains', 'tissue infections data', 'genbank databases bifidobacterium', 'rrna gene sequencing', 'biochemical identification strains', 'arcanobacterium haemolyticum strains', 'actinomyces species testing', 'cluster studied bifidobacterium', 'gene sequence databases']
# Current Micro Average F1@10 Score  0.0
# ['tests recombinant antigens', 'promising diagnostic methods', 'measures promising diagnostic', 'antibody tests recombinant', 'detection specific antibodies', 'antigen dna detection', 'development immunoreactive spots', 'recombinant antigens based', 'skin biopsy specimens', 'specific affordable diagnostic']
# Current Micro Average F1@10 Score  0.0
# ['sample german diabetologists', 'german diabetologists diabetologe', 'survey german diabetologists', 'german diabetologists diabetologen', 'german diabetologists table', 'habits german diabetologists', 'database german diabetologists', 'german diabetologists abstract', 'characteristics german diabetologists', 'german diabetologists performed']
# Current Micro Average F1@10 Score  0.0
# ['yeasts increasing importance', 'yeast genetics molecular', 'opportunistic yeasts increasing', 'yeast genetics', 'yeasts responsible nosocomial', 'conference yeast genetics', 'yeasts fastidious culture', 'fungal dna followed', 'fungal infections recently', 'databases containing fungal']
# Current Micro Average F1@10 Score  0.0
# ['aids vaccine dna', 'vector promising vaccine', 'promising aids vaccine', 'dna vaccines recombinant', 'vaccines recombinant viral', 'aids vaccines inducing', 'vaccine dna priming', 'efficacy aids vaccine', 'macaques vaccinated dna', 'promising vaccine tool']
# Current Micro Average F1@10 Score  0.0
# ['ypt1p gtpgammas recombinant', 'binding ypt1p gtpgammas', 'gtpgammas recombinant', 'gtpgammas presence recombinant', 'gtpgammas uptake ypt1p', 'ypt1p mediated fusion', 'gtpgammas recombinant gst', 'activity ypt1p gtpgammas', 'ypt32p recombinant ypt1p', 'recombinant ypt1p ypt32p']
# Current Micro Average F1@10 Score  0.0
# ['simulated bacteremia detected', 'processed simulated bacteremia', 'bacteremia detected child', 'simulated bacteremia assess', 'simulated bacteremia blood', 'detection simulated bacteremia', 'detecting odontogenic bacteremia', 'milliliter detection bacteremia', 'sample simulated bacteremia', 'estimating bacteremia simulated']
# Current Micro Average F1@10 Score  0.0
# ['apoptosis ndv infected', 'apoptosis rndv mutants', 'hemagglutinin titers virus', 'expressing virus rndv', 'rndv gfp viruses', 'hemagglutination assay infection', 'viruses paramyxoviruses use', 'apoptosis induced ndv', 'immunoglobulins dako viral', 'protein paramyxoviruses']
# Current Micro Average F1@10 Score  0.0
# ['vancomycin combination antibiotic', 'methicillin resistant staphylococcus', 'antibiotic quinupristin dalfopristin', 'combination antibiotic quinupristin', 'experimental endocarditis methicillin', 'lincosamide streptogramin resistance', 'streptogramin type antibiotics', 'methicillin resistant strains', 'antibiotic quinupristin', 'options include vancomycin']
# Current Micro Average F1@10 Score  0.0
# ['phosphorylation h2av drosophila', 'phosphorylation drosophila histone', 'h2av drosophila genome', 'drosophila h2az homolog', 'phosphorylation repair yeast', 'dna repair transcription', 'h2av dna repair', 'drosophila genome case', 'dna repair h2a', 'drosophila h2av phosphorylated']
# Current Micro Average F1@10 Score  0.0
# ['dna extract pcr', 'dna extraction highly', 'rapid pcr detection', 'sputum source dna', 'pcr detection burkholderia', 'pcr analysis sputum', 'yields dna extraction', 'pcr assay detects', 'instructions check dna', 'checked yields dna']
# Current Micro Average F1@10 Score  0.0
# ['antibiotic therapy lesions', 'mycobacterial arthritis lyme', 'therapy infectious arthritis', 'metaphysis intracapsular infection', 'arthritis antibiotic therapy', 'gonococcal arthritis diagnosis', 'infection phagocytosis bacteria', 'addition bacterial arthritis', 'diagnosis infectious arthritis', 'reactive arthritis antibiotic']
# Current Micro Average F1@10 Score  0.0
# ['hospitals use antibiotics', 'therapy nosocomial pneumonia', 'antibiotic classes help', 'hospital microbiology data', 'hospital antibiotic policy', 'antibiotic treatment courses', 'antibiotic deliveries hospital', 'hospital epidemiologist microbiology', 'influence hospital antibiotic', 'effects novel antibiotics']
# Current Micro Average F1@10 Score  0.0
# ['genetic homogeneity vancomycin', 'enterococci molecular epidemiology', 'analysis dendrogram genetic', 'genotypic diversity antibiotics', 'genogroup typing tn1546', 'patients grouped genetic', 'enterococci isolated human', 'strains showed genetic', 'antibiotics especially poultry', 'genetic poultry faecium']
# Current Micro Average F1@10 Score  0.0
# ['useful hcv genotyping', 'paper dried blood', 'detection genotyping hepatitis', 'pcr rna extraction', 'blood spots detection', 'rna dried blood', 'blood dilutions spotted', 'virus rna useful', 'genotyping hepatitis virus', 'serum dried plasma']
# Current Micro Average F1@10 Score  0.0
# ['recombinant protein drosophila', 'homologs yeast drosophila', 'p35 binds dna', 'yeast drosophila orc', 'yeast acs dna', 'insect cells baculovirus', 'gstcdc6 purification dna', 'polypeptide bound yeast', 'cells purification baculoviruses', 'cdc6 cloned pfastbac']
# Current Micro Average F1@10 Score  0.0
# ['lung epithelial carcinoma', 'pneumoniae infection cytokine', 'studies lung epithelial', 'vitro studies pneumoniae', 'pneumoniae infection centrifugation', 'pneumoniae particularly studies', 'epithelial carcinoma a549', 'carcinoma a549 cell', 'effects pneumoniae infection', 'pneumoniae infection intended']
# Current Micro Average F1@10 Score  0.0
# ['tuberculosis wild rodent', 'found wild rodents', 'wild rodents study', 'tb wild rodents', 'zoonotic infections rodents', 'previous study tuberculosis', 'tuberculosis mycobacterium bovis', 'mice apodemus sylvaticus', 'wild rodents sites', 'microti wild rodents']
# Current Micro Average F1@10 Score  0.0
# ['following spring grapevine', 'perennials grapevine annual', 'development cloned grapevine', 'grapevine annual herbaceous', 'process cloned grapevine', 'flower initiation grapevine', 'spring grapevine', 'grapevine bud development', 'flowering process grapevine', 'cloned grapevine floricaula']
# Current Micro Average F1@10 Score  0.0
# ['bacteria 105 inoculated', 'genome drug hypersusceptible', 'growing bacteria 105', 'parahaemolyticus encoded brucella', 'melitensis genome pumps', 'bacterial multidrug efflux', 'efflux protein parahaemolyticus', 'multidrug efflux protein', 'including antibiotics cells', 'inoculated ml trypticase']
# Current Micro Average F1@10 Score  0.0
# ['plant glycerophosphodiester phosphodiesterase', 'phosphodiesterase plants glycerophosphodiester', 'glycerophosphodiesters incubation carrot', 'seed germination glycerophosphodiesters', 'glycerophosphodiesters yeast saccharomyces', 'plants glycerophosphodiester accumulation', 'produces glycerophosphodiesters yeast', 'plant glycerophosphodiester', 'extracellular glycerophosphodiesters yeast', 'plant cells phosphatidylcholine']
# Current Micro Average F1@10 Score  0.0
# ['strychnine poisoning uncommon', 'strychnine overdose rare', 'strychnine poisoning past', 'severe strychnine poisoning', 'fatal poisoning patients', 'overdose rare', 'strychnine poisoning serum', 'fatal ingestion strychnine', 'strychnine poisoning favourable', 'fatal patient admitted']
# ...
# Current Micro Average F1@10 Score  0.0
# ['pathogenic mice pigs', 'porcine virus histopathologic', 'murine encephalomyelitis virus', 'porcine encephalomyocarditis virus', 'pfu mice infected', 'mice inoculated infectious', 'cardiovirus genus infects', 'encephalomyocarditis virus containing', 'cynomolgus macaques virus', 'infected recombinant viruses']
# Current Micro Average F1@10 Score  0.0
# ['studies difficile toxinotypes', 'variants toxin genes', 'pd3 m7 toxinotype', 'pd53 toxinotype vi', 'toxinotype contrary pd3', 'abi373a dna sequencer', 'toxinotyping pcr restriction', 'variations toxin genes', 'toxinotype vi pd3', '57267 controls toxinotypes']
# Current Micro Average F1@10 Score  0.0
# ['cancer develops women', 'cancer triage women', 'common cancer women', 'cancer women worldwide', 'cancer hiv positive', 'invasive carcinoma women', 'women hiv positive', 'positive women hiv', 'biopsy hiv positive', 'women infected hiv']
# Current Micro Average F1@10 Score  0.0
# ['assays additionally drosophila', 'elegans cut3 homolog', 'embryonic mitosis importin', 'mitosis immunolocalization nucleoporins', 'cell embryos immunofluorescence', 'mitotic chromosomes prometaphase', 'embryos stained dna', 'dna embryos hermaphrodites', 'mitosis involved nuclear', 'proteins caenorhabditis elegans']
# Current Micro Average F1@10 Score  0.0
# ['antibiotic treatment vancomycin', 'perioperative antibiotic prophylaxis', 'pharmacokinetics antibiotic tissue', 'administered perioperative antibiotic', 'tested susceptibilities vancomycin', 'methicillin resistant epidermidis', 'prophylactic antibiotic treatment', 'receive antibiotic prophylaxis', 'pharmacokinetics antibiotic', 'effective antibiotic prophylaxis']
# Current Micro Average F1@10 Score  0.0
# ['neuromodulin iq peptide', 'iq peptides assays', 'similarity iq3 peptide', 'myo1c iq peptides', 'iq peptides synthesized', 'iq3 peptide binds', 'iq peptides sample', 'reporter iq peptides', 'peptides data iq4', 'iq peptides assay']
# Current Micro Average F1@10 Score  0.0
# ['carcinogen glycidaldehyde reduced', 'mutagen carcinogen glycidaldehyde', 'carcinogen glycidaldehyde', 'chloroethyl nitrosoureas cancer', 'carcinogens found removed', 'nitrosoureas cancer therapy', 'mismatch uracil dna', 'reaction mutagen carcinogen', 'removed dna rodent', 'alkyladenine dna glycosylase']
# Current Micro Average F1@10 Score  0.0
# ['dna binding proteins', 'novel genetic programming', 'rna motif prediction', 'propose novel genetic', 'rna motif finding', 'predicted rna motifs', 'genetic programming rna', 'rnas interested finding', 'discover rna motifs', 'dna motifs rna']
# Current Micro Average F1@10 Score  0.0
# ['inhibition reduces cpla2', 'myocytes inhibition mek1', 'u0126 inhibits ca2', 'erk inhibition cpla2', 'prevents cpla2 translocation', 'kinases regulate cpla2', 'inhibits erk phosphorylation', 'preventing translocation cpla2', 'cpla2 mutated phosphorylation', 'inhibits ca2 mobilization']
# Current Micro Average F1@10 Score  0.0
# ['immunosorbent assay elisa', 'serum samples schistosomiasis', 'detection serum immunoglobulin', 'antigens haematobium elisa', 'antibody human immunoglobulin', 'elisa detecting schistosomiasis', 'tests detecting schistosomiasis', 'serodiagnosis imported schistosomiasis', 'worm antigens enzyme', 'iha test erythrocytes']
# Current Micro Average F1@10 Score  0.0
# ['alphacd28 increase protein', 'increased protein synthesis', 'increase protein synthesis', 'synthesis increase protein', 'protein synthesis increased', 'alphacd3 antibody stimulate', 'protein synthesis increase', 'antibodies increase eif2b', 's6 kinase increased', 'rate protein synthesis']
# Current Micro Average F1@10 Score  0.0
# ['methanol dried argon', 'ucb molecules small', 'h2b low solubility', 'low aqueous solubility', 'molecules small sediment', 'mixed solvents values', 'mbr slightly soluble', 'purified alkaline extraction', 'values weak acids', 'solubility mixed solvents']
# Current Micro Average F1@10 Score  0.0
# ['usually geriatrician nurse', 'geriatrician nurse therapist', 'patients care elderly', 'annual health check', 'health check 75s', 'medical care elderly', 'denmark elderly people', 'geriatric team trial', 'practice denmark elderly', 'scores 115 patients']
# Current Micro Average F1@10 Score  0.0
# ['isoenzymes neutrophils pregnant', 'baculovirus infected cells', 'fetuses sequenced neutrophil', 'blood collected neutrophils', 'pcr inserted baculovirus', 'blood neutrophils women', 'recombinant enzymes baculovirus', 'chorionic gonadotropin pregnancy', 'neutrophils pregnant women', 'stability neutrophils pregnant']
# Current Micro Average F1@10 Score  0.0
# ['uptake co2 photosynthesis', 'co2 concentration photosynthesis', 'co2 photosynthesis mediated', 'increase co2 efflux', 'eukaryotic algae increased', 'rapidly recycle co2', 'period photosynthesis substantially', 'algae increased number', 'ccm increasing co2', 'increasing co2 concentration']
# Current Micro Average F1@10 Score  0.0
# ['herpesvirus infections median', 'survey immunocompromised low', 'herpesvirus specific antiviral', 'hiv infected patients', 'human immunodeficiency virus', 'thymidine kinase negative', 'cancer human immunodeficiency', 'herpes simplex virus', 'herpesvirus resistance 11th', '62 isolates hiv']
# Current Micro Average F1@10 Score  0.0
# ['cardiology department pediatrics', 'columbia university biomarkers', 'division pediatric cardiology', 'pediatrics columbia university', 'nutrition department pediatrics', 'medicine columbia university', 'pediatric cardiology department', 'cardiovascular clinics pediatric', 'medicine department medicine', 'fitness test plasma']
# Current Micro Average F1@10 Score  0.0
# ['peptides novel antimicrobial', 'novel antimicrobial peptides', 'antibacterial peptides cathelicidin', 'sphingomyelin affinity antimicrobial', 'amphipathic antimicrobial peptides', 'antibacterial peptides diverse', 'peptides possess antibacterial', 'antimicrobial peptides cathelicidins', 'affinity antimicrobial peptides', 'helical antimicrobial peptides']
# Current Micro Average F1@10 Score  0.0
# ['qtbp42 destabilizes cgg', 'dna destabilizing tetraplex', 'telomeric dna destabilizing', 'tetraplex dna destabilization', 'tetraplex dna destabilizing', 'dna destabilization assay', 'destabilization tetraplex dna', 'dna oligonucleotides deoxyoligonucleotides', 'truncation mutations oligonucleotide', 'dna destabilization conditions']
# Current Micro Average F1@10 Score  0.0
# ['immunoblots sera patients', 'leishmaniasis studied immunoblot', 'examined patients antibody', 'detection antibodies patients', 'immunosorbent assay elisa', 'specific antileishmanial antibodies', 'patients mucocutaneous leishmaniasis', 'identify immunosuppressed patients', 'immunoglobulin specific antileishmanial', 'sag antibody tests']
# Current Micro Average F1@10 Score  0.0
# ['appendectomy young girl', 'specimens derived pneumonia', 'routine appendectomy adolescent', 'girl left hospital', 'local abscesses pneumonia', 'appendectomy signs fever', 'appendectomy adolescent blastobacter', 'immunocompromised patients reanalysis', 'meningitis routine diagnostic', 'hospital routine appendectomy']
# Current Micro Average F1@10 Score  0.0
# ['plants regulating gene', 'genes transformed arabidopsis', 'biosynthetic enzymes controlling', 'key biosynthetic enzymes', 'synthase key biosynthetic', 'transgenic arabidopsis plants', 'transgenic arabidopsis seedlings', 'expression transgenic plants', 'transformed arabidopsis plants', 'plant rhythms gene']
# Current Micro Average F1@10 Score  0.0
# ['arabinoxylan biosynthesis wheat', 'wheat seedlings catalyzed', 'biosynthesis wheat characterization', 'wheat arabinoxylan added', 'vesicles isolated wheat', 'wheat characterization arabinosyltransferase', 'xylan xylosyltransferase wheat', 'xylosyltransferase wheat enhanced', 'wheat seedlings addition', 'wheat seedlings microsomes']
# Current Micro Average F1@10 Score  0.0
# ['testing caspofungin yeasts', 'aspergillus isolates tested', 'tests broth microdilution', 'study potato dextrose', 'assay broth microdilution', 'testing caspofungin echinocandins', 'testing caspofungin aspergillus', 'broth microdilution assay', 'diffusion broth microdilution', 'broth microdilution tests']
# Current Micro Average F1@10 Score  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4338e97e2423> in <module>
#       7     kb = KeyBERT('distilbert-base-nli-mean-tokens')
#       8
# ----> 9     keywords = kb.extract_keywords(txt,
#      10                                       keyphrase_ngram_range = (1,3),
#      11                                       top_n = 10,
#
# ~\Anaconda3\lib\site-packages\keybert\model.py in extract_keywords(self, docs, candidates, keyphrase_ngram_range, stop_words, top_n, min_df, use_maxsum, use_mmr, diversity, nr_candidates, vectorizer)
#     103
#     104         if isinstance(docs, str):
# --> 105             return self._extract_keywords_single_doc(doc=docs,
#     106                                                      candidates=candidates,
#     107                                                      keyphrase_ngram_range=keyphrase_ngram_range,
#
# ~\Anaconda3\lib\site-packages\keybert\model.py in _extract_keywords_single_doc(self, doc, candidates, keyphrase_ngram_range, stop_words, top_n, use_maxsum, use_mmr, diversity, nr_candidates, vectorizer)
#     164             # Extract Embeddings
#     165             doc_embedding = self.model.embed([doc])
# --> 166             candidate_embeddings = self.model.embed(candidates)
#     167
#     168             # Calculate distances and extract keywords
#
# ~\Anaconda3\lib\site-packages\keybert\backend\_sentencetransformers.py in embed(self, documents, verbose)
#      51             that each have an embeddings size of `m`
#      52         """
# ---> 53         embeddings = self.embedding_model.encode(documents, show_progress_bar=verbose)
#      54         return embeddings
#
# ~\Anaconda3\lib\site-packages\sentence_transformers\SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     192
#     193             with torch.no_grad():
# --> 194                 out_features = self.forward(features)
#     195
#     196                 if output_value == 'token_embeddings':
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\sentence_transformers\models\Transformer.py in forward(self, features)
#      36             trans_features['token_type_ids'] = features['token_type_ids']
#      37
# ---> 38         output_states = self.auto_model(**trans_features, return_dict=False)
#      39         output_tokens = output_states[0]
#      40
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     480         if inputs_embeds is None:
#     481             inputs_embeds = self.embeddings(input_ids)  # (bs, seq_length, dim)
# --> 482         return self.transformer(
#     483             x=inputs_embeds,
#     484             attn_mask=attention_mask,
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     307                 all_hidden_states = all_hidden_states + (hidden_state,)
#     308
# --> 309             layer_outputs = layer_module(
#     310                 x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     311             )
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     265
#     266         # Feed Forward Network
# --> 267         ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     268         ffn_output = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     269
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\modeling_distilbert.py in forward(self, input)
#     216
#     217     def forward(self, input):
# --> 218         return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#     219
#     220     def ff_chunk(self, input):
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\modeling_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#    1698         return torch.cat(output_chunks, dim=chunk_dim)
#    1699
# -> 1700     return forward_fn(*input_tensors)
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\modeling_distilbert.py in ff_chunk(self, input)
#     221         x = self.lin1(input)
#     222         x = self.activation(x)
# --> 223         x = self.lin2(x)
#     224         x = self.dropout(x)
#     225         return x
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# KeyboardInterrupt:

# %%
sum(f1s)/len(f1s)
